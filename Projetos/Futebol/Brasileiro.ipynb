# %%
import pandas as pd
import sklearn

# %%
dados = pd.read_csv(r'C:\Users\User\Projetos análise de dados\analise-dados\Projetos\Futebol\BRA.csv')

# %%
dados.head()
# Out:
#   Country   League  Season        Date   Time          Home         Away   HG  \
# 0  Brazil  Serie A    2012  19/05/2012  22:30     Palmeiras   Portuguesa  1.0
# 1  Brazil  Serie A    2012  19/05/2012  22:30  Sport Recife  Flamengo RJ  1.0
# 2  Brazil  Serie A    2012  20/05/2012  01:00   Figueirense      Nautico  2.0
# 3  Brazil  Serie A    2012  20/05/2012  20:00   Botafogo RJ    Sao Paulo  4.0
# 4  Brazil  Serie A    2012  20/05/2012  20:00   Corinthians   Fluminense  0.0
#
#     AG Res    PH    PD    PA  MaxH  MaxD  MaxA  AvgH  AvgD  AvgA
# 0  1.0   D  1.75  3.86  5.25  1.76  3.87  5.31  1.69  3.50  4.90
# 1  1.0   D  2.83  3.39  2.68  2.83  3.42  2.70  2.59  3.23  2.58
# 2  1.0   H  1.60  4.04  6.72  1.67  4.05  7.22  1.59  3.67  5.64
# 3  2.0   H  2.49  3.35  3.15  2.49  3.39  3.15  2.35  3.26  2.84
# 4  1.0   A  1.96  3.53  4.41  1.96  3.53  4.41  1.89  3.33  3.89

# %%
dados.columns
# Out:
# Index(['Country', 'League', 'Season', 'Date', 'Time', 'Home', 'Away', 'HG',
#        'AG', 'Res', 'PH', 'PD', 'PA', 'MaxH', 'MaxD', 'MaxA', 'AvgH', 'AvgD',
#        'AvgA', 'resultado'],
#       dtype='object')

# %%
# agrupando as colunas em uma nova coluna
dados['resultado'] = dados.apply(lambda row: str(row['HG']) + " x " + str(row['AG']), axis=1)

# %%
dados.head()
# Out:
#   Country   League  Season        Date   Time          Home         Away   HG  \
# 0  Brazil  Serie A    2012  19/05/2012  22:30     Palmeiras   Portuguesa  1.0
# 1  Brazil  Serie A    2012  19/05/2012  22:30  Sport Recife  Flamengo RJ  1.0
# 2  Brazil  Serie A    2012  20/05/2012  01:00   Figueirense      Nautico  2.0
# 3  Brazil  Serie A    2012  20/05/2012  20:00   Botafogo RJ    Sao Paulo  4.0
# 4  Brazil  Serie A    2012  20/05/2012  20:00   Corinthians   Fluminense  0.0
#
#     AG Res    PH    PD    PA  MaxH  MaxD  MaxA  AvgH  AvgD  AvgA  resultado
# 0  1.0   D  1.75  3.86  5.25  1.76  3.87  5.31  1.69  3.50  4.90  1.0 x 1.0
# 1  1.0   D  2.83  3.39  2.68  2.83  3.42  2.70  2.59  3.23  2.58  1.0 x 1.0
# 2  1.0   H  1.60  4.04  6.72  1.67  4.05  7.22  1.59  3.67  5.64  2.0 x 1.0
# 3  2.0   H  2.49  3.35  3.15  2.49  3.39  3.15  2.35  3.26  2.84  4.0 x 2.0
# 4  1.0   A  1.96  3.53  4.41  1.96  3.53  4.41  1.89  3.33  3.89  0.0 x 1.0

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4180 entries, 0 to 4179
# Data columns (total 20 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    4180 non-null   object
#  1   League     4180 non-null   object
#  2   Season     4180 non-null   int64
#  3   Date       4180 non-null   object
#  4   Time       4180 non-null   object
#  5   Home       4180 non-null   object
#  6   Away       4180 non-null   object
#  7   HG         4179 non-null   float64
#  8   AG         4179 non-null   float64
#  9   Res        4179 non-null   object
#  10  PH         4179 non-null   float64
#  11  PD         4179 non-null   float64
#  12  PA         4179 non-null   float64
#  13  MaxH       4180 non-null   float64
#  14  MaxD       4180 non-null   float64
#  15  MaxA       4180 non-null   float64
#  16  AvgH       4180 non-null   float64
#  17  AvgD       4180 non-null   float64
#  18  AvgA       4180 non-null   float64
# ...

# %%
# converter a coluna para int
dados['HG'] = dados['HG'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In [7], line 2
#       1 # converter a coluna para int
# ----> 2 dados['HG'] = dados['HG'].astype(int)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# ...

# %%
# converter a coluna para int
dados['AG'] = dados['AG'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In [10], line 2
#       1 # converter a coluna para int
# ----> 2 dados['AG'] = dados['AG'].astype(int)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# ...

# %%
dados['AG'] = dados['AG'].fillna(0).astype(int)

# %%
dados['HG'] = dados['HG'].fillna(0).astype(int)

# %%
dados.head()
# Out:
#   Country   League  Season        Date   Time          Home         Away  HG  \
# 0  Brazil  Serie A    2012  19/05/2012  22:30     Palmeiras   Portuguesa   1
# 1  Brazil  Serie A    2012  19/05/2012  22:30  Sport Recife  Flamengo RJ   1
# 2  Brazil  Serie A    2012  20/05/2012  01:00   Figueirense      Nautico   2
# 3  Brazil  Serie A    2012  20/05/2012  20:00   Botafogo RJ    Sao Paulo   4
# 4  Brazil  Serie A    2012  20/05/2012  20:00   Corinthians   Fluminense   0
#
#    AG Res    PH    PD    PA  MaxH  MaxD  MaxA  AvgH  AvgD  AvgA  resultado
# 0   1   D  1.75  3.86  5.25  1.76  3.87  5.31  1.69  3.50  4.90  1.0 x 1.0
# 1   1   D  2.83  3.39  2.68  2.83  3.42  2.70  2.59  3.23  2.58  1.0 x 1.0
# 2   1   H  1.60  4.04  6.72  1.67  4.05  7.22  1.59  3.67  5.64  2.0 x 1.0
# 3   2   H  2.49  3.35  3.15  2.49  3.39  3.15  2.35  3.26  2.84  4.0 x 2.0
# 4   1   A  1.96  3.53  4.41  1.96  3.53  4.41  1.89  3.33  3.89  0.0 x 1.0

# %%
dados['AG'] = dados['AG'].fillna(0).astype(int)

# %%
# converter a coluna para int
dados['AG'] = dados['AG'].astype(int)

# %%
# agrupando as colunas em uma nova coluna
dados['resultado'] = dados.apply(lambda row: str(row['HG']) + " x " + str(row['AG']), axis=1)

# %%
dados.head()
# Out:
#   Country   League  Season        Date   Time          Home         Away  HG  \
# 0  Brazil  Serie A    2012  19/05/2012  22:30     Palmeiras   Portuguesa   1
# 1  Brazil  Serie A    2012  19/05/2012  22:30  Sport Recife  Flamengo RJ   1
# 2  Brazil  Serie A    2012  20/05/2012  01:00   Figueirense      Nautico   2
# 3  Brazil  Serie A    2012  20/05/2012  20:00   Botafogo RJ    Sao Paulo   4
# 4  Brazil  Serie A    2012  20/05/2012  20:00   Corinthians   Fluminense   0
#
#    AG Res    PH    PD    PA  MaxH  MaxD  MaxA  AvgH  AvgD  AvgA resultado
# 0   1   D  1.75  3.86  5.25  1.76  3.87  5.31  1.69  3.50  4.90     1 x 1
# 1   1   D  2.83  3.39  2.68  2.83  3.42  2.70  2.59  3.23  2.58     1 x 1
# 2   1   H  1.60  4.04  6.72  1.67  4.05  7.22  1.59  3.67  5.64     2 x 1
# 3   2   H  2.49  3.35  3.15  2.49  3.39  3.15  2.35  3.26  2.84     4 x 2
# 4   1   A  1.96  3.53  4.41  1.96  3.53  4.41  1.89  3.33  3.89     0 x 1

# %%
total_gols = dados.loc[dados['Home'] == 'Palmeiras', 'AG'].sum()
print(total_gols)
# Out:
# 176

# %%
# agrupar os dados por time
gols_por_time = dados.groupby(['Home']).agg({'HG': 'sum', 'AG': 'sum'}).reset_index()

# somar os gols totais e adicionar a coluna correspondente
gols_por_time['Total'] = gols_por_time['HG'] + gols_por_time['AG']

# imprimir o resultado
print(gols_por_time)
# Out:
#               Home   HG   AG  Total
# 0       America MG   79   66    145
# 1     Athletico-PR  100   62    162
# 2      Atletico GO  102  111    213
# 3      Atletico-MG  380  191    571
# 4      Atletico-PR  193   91    284
# 5             Avai   75   96    171
# 6            Bahia  189  150    339
# 7      Botafogo RJ  221  177    398
# 8       Bragantino   91   62    153
# 9              CSA   17   24     41
# 10           Ceara  107   91    198
# 11  Chapecoense-SC  149  142    291
# 12     Corinthians  303  152    455
# 13        Coritiba  189  133    322
# 14        Criciuma   45   45     90
# 15        Cruzeiro  237  140    377
# 16          Cuiaba   35   35     70
# 17     Figueirense   86   82    168
# 18     Flamengo RJ  358  187    545
# 19      Fluminense  309  201    510
# 20       Fortaleza   96   64    160
# 21           Goias  149  120    269
# 22          Gremio  298  148    446
# 23   Internacional  307  161    468
# 24       Joinville   19   17     36
# ...

# %%
gols_por_time.to_csv('gols_por_time.csv', index=False)

# %%
gols_sofridos_por_time = dados.groupby(['Away']).agg({'HG': 'sum', 'AG': 'sum'}).reset_index()
gols_sofridos_por_time.columns = ['Time', 'Gols_sofridos_em_casa', 'Gols_sofridos_fora']
gols_sofridos_por_time['Gols_sofridos_total'] = gols_sofridos_por_time['Gols_sofridos_em_casa'] + gols_sofridos_por_time['Gols_sofridos_fora']
print(gols_sofridos_por_time)
# Out:
#               Time  Gols_sofridos_em_casa  Gols_sofridos_fora  \
# 0       America MG                    116                  55
# 1     Athletico-PR                     99                  78
# 2      Atletico GO                    150                  85
# 3      Atletico-MG                    276                 239
# 4      Atletico-PR                    160                  95
# 5             Avai                    134                  44
# 6            Bahia                    221                 139
# 7      Botafogo RJ                    239                 155
# 8       Bragantino                     83                  63
# 9              CSA                     34                   7
# 10           Ceara                    118                  88
# 11  Chapecoense-SC                    217                 112
# 12     Corinthians                    229                 198
# 13        Coritiba                    266                 132
# ...

# %%
#gerando arquivo csv
gols_sofridos_por_time.to_csv('gols_sofridos_por_time.csv', index=False)

# %%
import pandas as pd

# carregar os dados do arquivo CSV
dados = pd.read_csv(r'C:\Users\User\Projetos análise de dados\analise-dados\Projetos\Futebol\BRA.csv')

# criar função para definir resultados de cada jogo
def definir_resultado(linha):
    if linha['Res'] == 'H':
        return 'Vitoria'
    elif linha['Res'] == 'A':
        return 'Derrota'
    else:
        return 'Empate'
# criar função para calcular a pontuação
def calcular_pontos(linha):
    return linha['Vitoria'] * 3 + linha['Empate']



# agrupar os dados por time e resultado e calcular as contagens
resultados_por_time = dados.groupby(['Home', 'Resultado']).size().reset_index(name='Contagem')

# pivotar a tabela para ter uma coluna para cada tipo de resultado
resultados_por_time = resultados_por_time.pivot(index='Home', columns='Resultado', values='Contagem')

# preencher valores NaN com zero
resultados_por_time = resultados_por_time.fillna(0)

# calcular o número total de jogos de cada time
resultados_por_time['Total'] = resultados_por_time['Vitoria'] + resultados_por_time['Derrota'] + resultados_por_time['Empate']
# aplicar função para criar coluna "Pontos"
resultados_por_time['Pontos'] = resultados_por_time.apply(calcular_pontos, axis=1)


# salvar o resultado em um arquivo CSV
resultados_por_time.to_csv('resultados_por_time.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [48], line 21
#      16     return linha['Vitoria'] * 3 + linha['Empate']
#      20 # agrupar os dados por time e resultado e calcular as contagens
# ---> 21 resultados_por_time = dados.groupby(['Home', 'Resultado']).size().reset_index(name='Contagem')
#      23 # pivotar a tabela para ter uma coluna para cada tipo de resultado
#      24 resultados_por_time = resultados_por_time.pivot(index='Home', columns='Resultado', values='Contagem')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:8389, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8386     raise TypeError("You have to supply one of 'by' and 'level'")
#    8387 axis = self._get_axis_number(axis)
# -> 8389 return DataFrameGroupBy(
#    8390     obj=self,
# ...

# %%
como criar um arquivo de banco de dados reunindo informaçoes de gols feitos em casa, fora, total de gols, gols sofridos em casa, fora, total e numero de vitorias, empates e vitorias

# %%
# Calculando a pontuação de cada time
resultados_por_time['Pontos'] = resultados_por_time['Vitoria']*3 + resultados_por_time['Empate']

# Ordenando o DataFrame pela pontuação de forma decrescente
resultados_por_time = resultados_por_time.sort_values(by='Pontos', ascending=False)

# Salvando o resultado em um arquivo CSV
resultados_por_time.to_csv('pontuacao.csv', index=False)

# %%
# Agrupando por time e contabilizando vitórias, derrotas e empates
resultados_por_time = dados.groupby(['Home']).agg({'Res': lambda x: x.map({'H': 1, 'D': 0, 'A': -1}).sum(),
                                                   'Away': 'count'}).reset_index()

# Renomeando as colunas
resultados_por_time = resultados_por_time.rename(columns={'Res': 'Vitoria', 'Away': 'Jogos'})

# Adicionando colunas de derrotas e empates
resultados_por_time['Derrota'] = resultados_por_time['Jogos'] - resultados_por_time['Vitoria']
resultados_por_time['Empate'] = resultados_por_time['Jogos'] - resultados_por_time['Vitoria'] - resultados_por_time['Derrota']

# Adicionando coluna de pontos
resultados_por_time['Pontos'] = resultados_por_time['Vitoria']*3 + resultados_por_time['Empate']

# Ordenando o DataFrame pela pontuação de forma decrescente
resultados_por_time = resultados_por_time.sort_values(by='Pontos', ascending=False)

# Exibindo os nomes dos times e salvando o resultado em um arquivo CSV
resultados_por_time[['Home', 'Vitoria','Empate','Derrota','Pontos']].to_csv('pontuacao.csv', index=False)

# %%
import pandas as pd

#carregar os dados do arquivo CSV
dados = pd.read_csv(r'C:\Users\User\Projetos análise de dados\analise-dados\Projetos\Futebol\BRA.csv')

#criar função para definir resultados de cada jogo
def definir_resultado(linha):
    if linha['Res'] == 'H':
        return 'Vitoria'
    elif linha['Res'] == 'A':
        return 'Derrota'
    else:
        return 'Empate'

#aplicar função para criar coluna "Resultado"
dados['Resultado'] = dados.apply(definir_resultado, axis=1)

#agrupar os dados por time e resultado e calcular as contagens
resultados_por_time = dados.groupby(['Home', 'Resultado']).size().reset_index(name='Contagem')

#pivotar a tabela para ter uma coluna para cada tipo de resultado
resultados_por_time = resultados_por_time.pivot(index='Home', columns='Resultado', values='Contagem')

#preencher valores NaN com zero
resultados_por_time = resultados_por_time.fillna(0)

#calcular o número total de jogos de cada time
resultados_por_time['Total'] = resultados_por_time['Vitoria'] + resultados_por_time['Derrota'] + resultados_por_time['Empate']

#calcular a pontuação de cada time
resultados_por_time['Pontos'] = resultados_por_time['Vitoria'] * 3 + resultados_por_time['Empate']

#ordenar o DataFrame pela pontuação de forma decrescente
resultados_por_time = resultados_por_time.sort_values(by='Pontos', ascending=False)

#salvar o resultado em um arquivo CSV
resultados_por_time.to_csv('resultados_por_time.csv')

# %%
import pandas as pd
import sqlite3

# carregar os dados do arquivo CSV
dados = pd.read_csv(r'C:\Users\User\Projetos análise de dados\analise-dados\Projetos\Futebol\BRA.csv')

# criar função para definir resultados de cada jogo
def definir_resultado(linha):
    if linha['Res'] == 'H':
        return 'Vitoria'
    elif linha['Res'] == 'A':
        return 'Derrota'
    else:
        return 'Empate'

# aplicar função para criar coluna "Resultado"
dados['Resultado'] = dados.apply(definir_resultado, axis=1)

# agrupar os dados por time e calcular as estatísticas
gols_por_time = dados.groupby(['Home']).agg({'HG': 'sum', 'AG': 'sum'}).reset_index()
gols_sofridos_por_time = dados.groupby(['Home']).agg({'AG': 'sum', 'HG': 'sum'}).reset_index()
resultados_por_time = dados.groupby(['Home', 'Resultado']).size().reset_index(name='Contagem')
resultados_por_time = resultados_por_time.pivot(index='Home', columns='Resultado', values='Contagem').fillna(0)
resultados_por_time['Total'] = resultados_por_time['Vitoria'] + resultados_por_time['Derrota'] + resultados_por_time['Empate']
resultados_por_time['Pontos'] = resultados_por_time['Vitoria']*3 + resultados_por_time['Empate']

# juntar as informações em um único dataframe
dados_agrupados = gols_por_time.merge(gols_sofridos_por_time, on='Home', suffixes=['_feitos', '_sofridos'])
dados_agrupados = dados_agrupados.merge(resultados_por_time, on='Home')

# criar conexão com o banco de dados
conn = sqlite3.connect('dados_futebol.db')

# criar tabela para armazenar os dados
conn.execute('''CREATE TABLE IF NOT EXISTS dados_futebol
                (time TEXT, gols_casa INTEGER, gols_fora INTEGER, total_gols INTEGER, 
                 gols_sofridos_casa INTEGER, gols_sofridos_fora INTEGER, total_gols_sofridos INTEGER, 
                 vitorias INTEGER, empates INTEGER, derrotas INTEGER, total_jogos INTEGER, pontos INTEGER)''')

# inserir os dados na tabela
for row in dados_agrupados.itertuples(index=False):
    conn.execute(f"INSERT INTO dados_futebol VALUES ('{row.Home}', {row.HG_feitos}, {row.AG_feitos}, {row.HG_feitos + row.AG_feitos}, {row.HG_sofridos}, {row.AG_sofridos}, {row.HG_sofridos + row.AG_sofridos}, {row.Vitoria}, {row.Empate}, {row.Derrota}, {row.Total}, {row.Pontos})")

# commitar as mudanças e fechar a conexão
conn.commit()
conn.close()

# %%
import pandas as pd
import sqlite3

# conectar com o banco de dados
conn = sqlite3.connect('dados_futebol.db')

# executar consulta SQL para obter os dados
dados = pd.read_sql_query("SELECT * FROM dados_futebol", conn)

# salvar os dados em um arquivo CSV
dados.to_csv('dados_futebol.csv', index=False)

# fechar a conexão com o banco de dados
conn.close()
